# %%
import torch
import matplotlib.pyplot as plt

# Generar datos sintéticos
data = torch.randn(1000)

# Calcular media y desviación estándar
mean = torch.mean(data)
std = torch.std(data)

print(f'Media: {mean.item():.2f}, Desviación Estándar: {std.item():.2f}')

# Histograma
plt.hist(data.numpy(), bins=30)
plt.title('Histograma de Datos Sintéticos')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %%
import torch.nn as nn

nn.init.xavier_uniform_(layer.weight)

# %%
import torch
import matplotlib.pyplot as plt

# Generar datos
mean = 5
std_dev = 2
data = torch.normal(mean, std_dev, size=(1000,))

# Visualización
plt.hist(data.numpy(), bins=30)
plt.title('Distribución Normal (μ=5, σ=2)')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
